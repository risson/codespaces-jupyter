# %%
from pytdx.config.hosts import hq_hosts
import pandas as pd
from pytdx.hq import TdxHq_API
import seaborn as sns

from smtplib import SMTP
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

import time

# %%
index_lst = [(1, '000001','上证指数'), 
          (0, '399001','深证成指'), 
          (0, '399006','创业板指')]

# %%
def bollinger_bands(df, n, m):
    # takes dataframe on input
    # n = smoothing length
    # m = number of standard deviations away from MA
    
    #typical price
    TP = (df['high'] + df['low'] + df['close']) / 3
    # but we will use Adj close instead for now, depends
    
    data = df['close']
    #data = TP
    #data = df['Adj Close']
    
    # takes one column from dataframe
    B_MA = pd.Series((data.rolling(n, min_periods=n).mean()), name='B_MA')
    sigma = data.rolling(n, min_periods=n).std() 
    
    BU = pd.Series((B_MA + m * sigma), name='BU')
    BL = pd.Series((B_MA - m * sigma), name='BL')
    
    df = df.join(B_MA)
    df = df.join(BU)
    df = df.join(BL)
    
    return df


def send_mail(subjectline, body, to_addr):

    host = "smtp.tom.com"
    port = 25
    from_addr = "risson_chanlun@tom.com"
    sender_email = "risson_chanlun@tom.com"
    paaa = "Chanlun_365"

    message = MIMEMultipart()
    message.attach(MIMEText(body, "html"))
    message['Subject'] = subjectline
    message['From'] = from_addr
    message['To'] = to_addr
    msg_body = message.as_string()
   
    with SMTP(host, port) as server:
        server.login(sender_email, paaa)
        server.sendmail(message['From'], message['To'], msg_body)

    print("Sent!")

# %%
ticktock =  0
while ticktock<120:

    api = TdxHq_API()
    host = hq_hosts[11]
    n = 480   # datapoint rolling window
    m = 2    # sigma width

    df_index1 = []
    boll_index1 = []

    if api.connect(host[1], host[2]):
        print('Connected!')

        for stock in index_lst:
            df = api.to_df(api.get_security_bars(8, stock[0], stock[1], 0, 500)) # 30 min k lines
            df_index1+= [df]

        api.disconnect()

    else:   
        send_mail("布林程序连接数据失败","布林监控程序连接通达信数据失败","270156760@qq.com")

    for df in df_index1:
        boll_index1 += [bollinger_bands(df, n, m)]
        
    for i in range(len(df_index1)):
        boll = boll_index1[i]
        if boll.iloc[-2]['high'] < boll.iloc[-2]['BU'] and boll.iloc[-1]['high'] >= boll.iloc[-2]['BU']:
            stock_nm = index_lst[i][2]
            subject = f"[{stock_nm}] 1F布林上穿上轨"
            body = f"时间：{boll.iloc[-1]['datetime']}，现价：{boll.iloc[-1]['close']}"
            send_mail(subject,body,"270156760@qq.com")
        if (boll.iloc[-3]['low'] > boll.iloc[-3]['BU'] or boll.iloc[-2]['low'] > boll.iloc[-2]['BU']) and boll.iloc[-1]['low'] <= boll.iloc[-2]['BU']:
            stock_nm = index_lst[i][2]
            subject = f"[{stock_nm}] 1F布林下穿上轨"
            body = f"时间：{boll.iloc[-1]['datetime']}，现价：{boll.iloc[-1]['close']}"
            send_mail(subject,body,"270156760@qq.com")

    ticktock += 1
    time.sleep(60)
# Out:
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# Connected!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'high'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 25
#      22     send_mail("布林程序连接数据失败","布林监控程序连接通达信数据失败","270156760@qq.com")
#      24 for df in df_index1:
# ---> 25     boll_index1 += [bollinger_bands(df, n, m)]
#      27 for i in range(len(df_index1)):
#      28     boll = boll_index1[i]
#
# Cell In[3], line 7, in bollinger_bands(df, n, m)
#       1 def bollinger_bands(df, n, m):
#       2     # takes dataframe on input
#       3     # n = smoothing length
#       4     # m = number of standard deviations away from MA
#       5
#       6     #typical price
# ----> 7     TP = (df['high'] + df['low'] + df['close']) / 3
#       8     # but we will use Adj close instead for now, depends
#      10     data = df['close']
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'high'
